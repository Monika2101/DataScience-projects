# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv("Desktop/Data/school_census_dataset.csv")

# %%
data.head(5)
# Out:
#    Year                Region  Gender   Age      Country New Zealand European  \
# 0    10     Wellington Region  female  14.0  New Zealand                  yes
# 1    12  Bay of Plenty Region    male  16.0  New Zealand                  yes
# 2     7       Auckland Region  female  11.0  New Zealand                   no
# 3     7        Waikato Region  female  11.0  New Zealand                  yes
# 4    13     Canterbury Region  female  17.0  New Zealand                  yes
#
#   Maori Samoan Cook Islands Maori Tongan  ...  \
# 0    no     no                 no     no  ...
# 1    no     no                 no     no  ...
# 2    no    yes                yes     no  ...
# 3   yes     no                 no     no  ...
# 4    no     no                 no     no  ...
#
#   How true: It is easy for me to make friends  \
# 0                                        30.0
# 1                                       -45.0
# 2                                        46.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 78 columns):
# Year                                                                                        1000 non-null int64
# Region                                                                                      1000 non-null object
# Gender                                                                                      998 non-null object
# Age                                                                                         989 non-null float64
# Country                                                                                     997 non-null object
# New Zealand European                                                                        1000 non-null object
# Maori                                                                                       1000 non-null object
# ...

# %% [markdown]
# #finding null value

# %%
data.isnull().sum()
# Out:
# Year                                                                                          0
# Region                                                                                        0
# Gender                                                                                        2
# Age                                                                                          11
# Country                                                                                       3
# New Zealand European                                                                          0
# Maori                                                                                         0
# Samoan                                                                                        0
# Cook Islands Maori                                                                            0
# Tongan                                                                                        0
# ...

# %%
data.drop(data.iloc[:, 64:78], axis=1 , inplace=True)

# %% [markdown]
# #Removing columns with null values

# %%
data.drop(["Other ethnicity","Wrist circumference","Bag weight","Screen time opinion - On your phone","Screen time opinion - On social media"], axis=1 , inplace=True)

# %%
data.head()
# Out:
#    Year                Region  Gender   Age      Country New Zealand European  \
# 0    10     Wellington Region  female  14.0  New Zealand                  yes
# 1    12  Bay of Plenty Region    male  16.0  New Zealand                  yes
# 2     7       Auckland Region  female  11.0  New Zealand                   no
# 3     7        Waikato Region  female  11.0  New Zealand                  yes
# 4    13     Canterbury Region  female  17.0  New Zealand                  yes
#
#   Maori Samoan Cook Islands Maori Tongan  ...  \
# 0    no     no                 no     no  ...
# 1    no     no                 no     no  ...
# 2    no    yes                yes     no  ...
# 3   yes     no                 no     no  ...
# 4    no     no                 no     no  ...
#
#   Feeling without phone - Relieved Feeling without phone - Sad  \
# 0                              yes                          no
# 1                               no                          no
# ...

# %%
data.isnull().sum()
# Out:
# Year                                           0
# Region                                         0
# Gender                                         2
# Age                                           11
# Country                                        3
# New Zealand European                           0
# Maori                                          0
# Samoan                                         0
# Cook Islands Maori                             0
# Tongan                                         0
# Niuean                                         0
# Chinese                                        0
# Indian                                         0
# Languages spoken                              49
# Eye Colour                                     0
# Handedness                                     6
# Height                                        36
# Right foot length                             26
# Left thumb circumference                      61
# ...

# %%
data.drop(["Check messages as soon as you wake up", "Respond to messages immediately", "Take phone to school",
                              "Lose focus as school due to phone", "Bed time", "Wake time","Time you get home from school","Time you ate dinner"],axis=1, inplace=True)

# %%
data.isnull().sum()
# Out:
# Year                                          0
# Region                                        0
# Gender                                        2
# Age                                          11
# Country                                       3
# New Zealand European                          0
# Maori                                         0
# Samoan                                        0
# Cook Islands Maori                            0
# Tongan                                        0
# Niuean                                        0
# Chinese                                       0
# Indian                                        0
# Languages spoken                             49
# Eye Colour                                    0
# Handedness                                    6
# Height                                       36
# Right foot length                            26
# Left thumb circumference                     61
# Travel method to school                       8
# ...

# %%
data.head()
# Out:
#    Year                Region  Gender   Age      Country New Zealand European  \
# 0    10     Wellington Region  female  14.0  New Zealand                  yes
# 1    12  Bay of Plenty Region    male  16.0  New Zealand                  yes
# 2     7       Auckland Region  female  11.0  New Zealand                   no
# 3     7        Waikato Region  female  11.0  New Zealand                  yes
# 4    13     Canterbury Region  female  17.0  New Zealand                  yes
#
#   Maori Samoan Cook Islands Maori Tongan  ... Feeling without phone - Anxious  \
# 0    no     no                 no     no  ...                             yes
# 1    no     no                 no     no  ...                              no
# 2    no    yes                yes     no  ...                              no
# 3   yes     no                 no     no  ...                              no
# 4    no     no                 no     no  ...                             yes
#
# ...

# %%
data["Physical activity - before school"] = data["Physical activity - before school"].str.split('+').str[0]

# %%
data["Physical activity - at school"] = data["Physical activity - at school"].str.split('+').str[0]

# %%
data["Physical activity - after school"] = data["Physical activity - after school"].str.split('+').str[0]

# %%
data.iloc[:,26:28] = data.iloc[:,26:28].astype(float)

# %%
data_object = data.select_dtypes(include=['object'])

# %%
data_object.head()
# Out:
#                  Region  Gender      Country New Zealand European Maori  \
# 0     Wellington Region  female  New Zealand                  yes    no
# 1  Bay of Plenty Region    male  New Zealand                  yes    no
# 2       Auckland Region  female  New Zealand                   no    no
# 3        Waikato Region  female  New Zealand                  yes   yes
# 4     Canterbury Region  female  New Zealand                  yes    no
#
#   Samoan Cook Islands Maori Tongan Niuean Chinese  ...  \
# 0     no                 no     no     no      no  ...
# 1     no                 no     no     no      no  ...
# 2    yes                yes     no     no     yes  ...
# 3     no                 no     no     no      no  ...
# 4     no                 no     no     no      no  ...
#
#   Feeling without phone - Angry Feeling without phone - Anxious  \
# 0                            no                             yes
# 1                            no                              no
# ...

# %%
data_object.isnull().sum()
# Out:
# Region                                        0
# Gender                                        2
# Country                                       3
# New Zealand European                          0
# Maori                                         0
# Samoan                                        0
# Cook Islands Maori                            0
# Tongan                                        0
# Niuean                                        0
# Chinese                                       0
# Indian                                        0
# Eye Colour                                    0
# Handedness                                    6
# Travel method to school                       8
# Litter in lunch                              13
# Physical activity - after school             33
# Favourite video game                         77
# Own cell phone                               13
# Facebook account                             13
# Instagram account                            13
# ...

# %%
data_object = data_object.drop(['Favourite video game'], axis=1)

# %%
data_nu= data._get_numeric_data()

# %%
data_nu.fillna(data_nu.mean(), inplace = True)

# %%
data_nu.head()
# Out:
#    Year   Age  Languages spoken  Height  Right foot length  \
# 0    10  14.0               2.0   164.0               25.0
# 1    12  16.0               1.0   179.0               27.0
# 2     7  11.0               1.0   165.0               24.0
# 3     7  11.0               1.0   153.0               26.0
# 4    13  17.0               1.0   166.0               26.0
#
#    Left thumb circumference  Travel time to school  Fruit/vegetables in lunch  \
# 0                       7.0                    3.0                        2.0
# 1                       7.0                   10.0                        1.0
# 2                       6.0                   15.0                        4.0
# 3                       5.0                   20.0                        2.0
# 4                       7.0                    1.0                        1.0
#
#    Memory time  Reaction time  Time standing on left leg  \
# 0         26.0          0.375                       27.0
# ...

# %%
data_nu.isnull().sum()
# Out:
# Year                                  0
# Age                                   0
# Languages spoken                      0
# Height                                0
# Right foot length                     0
# Left thumb circumference              0
# Travel time to school                 0
# Fruit/vegetables in lunch             0
# Memory time                           0
# Reaction time                         0
# Time standing on left leg             0
# Physical activity - before school     0
# Physical activity - at school         0
# Physical activity - on the weekend    0
# Scheduled activities in last week     0
# Screen time after school              0
# Sleep time                            0
# dtype: int64

# %%
census_final_data = pd.concat([data_nu,data_object],axis=1)

# %%
census_final_data.head()
# Out:
#    Year   Age  Languages spoken  Height  Right foot length  \
# 0    10  14.0               2.0   164.0               25.0
# 1    12  16.0               1.0   179.0               27.0
# 2     7  11.0               1.0   165.0               24.0
# 3     7  11.0               1.0   153.0               26.0
# 4    13  17.0               1.0   166.0               26.0
#
#    Left thumb circumference  Travel time to school  Fruit/vegetables in lunch  \
# 0                       7.0                    3.0                        2.0
# 1                       7.0                   10.0                        1.0
# 2                       6.0                   15.0                        4.0
# 3                       5.0                   20.0                        2.0
# 4                       7.0                    1.0                        1.0
#
#    Memory time  Reaction time  ...  Feeling without phone - Angry  \
# 0         26.0          0.375  ...                             no
# ...

# %%
census_final_data=census_final_data.dropna()

# %%
census_final_data.head()
# Out:
#    Year   Age  Languages spoken  Height  Right foot length  \
# 0    10  14.0               2.0   164.0               25.0
# 1    12  16.0               1.0   179.0               27.0
# 4    13  17.0               1.0   166.0               26.0
# 5     9  13.0               1.0   155.0               24.0
# 6    10  14.0               2.0   159.0               24.0
#
#    Left thumb circumference  Travel time to school  Fruit/vegetables in lunch  \
# 0                       7.0                    3.0                        2.0
# 1                       7.0                   10.0                        1.0
# 4                       7.0                    1.0                        1.0
# 5                       6.0                   63.0                        3.0
# 6                       6.0                   35.0                        4.0
#
#    Memory time  Reaction time  ...  Feeling without phone - Angry  \
# 0         26.0       0.375000  ...                             no
# ...

# %%
census_final_data = census_final_data.replace('n/a', np.nan)

# %%
census_final_data.head()
# Out:
#    Year   Age  Languages spoken  Height  Right foot length  \
# 0    10  14.0               2.0   164.0               25.0
# 1    12  16.0               1.0   179.0               27.0
# 4    13  17.0               1.0   166.0               26.0
# 5     9  13.0               1.0   155.0               24.0
# 6    10  14.0               2.0   159.0               24.0
#
#    Left thumb circumference  Travel time to school  Fruit/vegetables in lunch  \
# 0                       7.0                    3.0                        2.0
# 1                       7.0                   10.0                        1.0
# 4                       7.0                    1.0                        1.0
# 5                       6.0                   63.0                        3.0
# 6                       6.0                   35.0                        4.0
#
#    Memory time  Reaction time  ...  Feeling without phone - Angry  \
# 0         26.0       0.375000  ...                             no
# ...

# %%
census_final_data.isnull().sum()
# Out:
# Year                                         0
# Age                                          0
# Languages spoken                             0
# Height                                       0
# Right foot length                            0
# Left thumb circumference                     0
# Travel time to school                        0
# Fruit/vegetables in lunch                    0
# Memory time                                  0
# Reaction time                                0
# Time standing on left leg                    0
# Physical activity - before school            0
# Physical activity - at school                0
# Physical activity - on the weekend           0
# Scheduled activities in last week            0
# Screen time after school                     0
# Sleep time                                   0
# Region                                       0
# Gender                                       0
# Country                                      0
# ...

# %%
census_final_data['Gender'].value_counts().plot.bar()

# %% [markdown]
# #Females are more than males

# %%
sns.countplot(y='Age', hue='Gender', data=census_final_data)

# %% [raw]
# #most student are in age b/w 8 to 16

# %%
correlation = census_final_data.corr()
plt.figure(figsize=(14,14))
sns.heatmap(census_final_data.corr(), annot=True)

# %% [markdown]
# #Year are Highly correlated with Height, Age, Memory Time, Physical activity - at school, Sleep Time
# #Age is Highly correlated with Height, Memory Time, Physical activity - at school, Sleep Time
# #Height is Highly correlated with Memory Time, Physical activity - at school, Sleep Time
# #Travel time to school and Sleep Time are correlated
# #Physical activity - at school and Screen time after school are correlated
# #Screen time after school are correlated with Fruit/vegetables in lunch and Physical activity - on the weekend

# %%
sns.boxplot(x = 'Travel time to school', y = 'Region', data = census_final_data)

# %% [raw]
# # west cost student are spending alot of time in travelling to school

# %%
pd.set_option('display.max_columns', None)
sns.distplot(census_final_data['Sleep time'], kde=False)
# Out:
# C:\Users\Monika\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [raw]
# #large number of student sleeps between 6 to 12 hrs

# %%
census_final_data['Travel method to school'].value_counts().plot.bar()

# %% [raw]
# # Most of the student use motor as travel method to school

# %%
sns.countplot(y='Own cell phone', hue='Gender', data=census_final_data)

# %%
census_final_data['Instagram account'].value_counts().plot.bar()

# %%
census_final_data['Facebook account'].value_counts().plot.bar()

# %%
census_final_data['Snapchat account'].value_counts().plot.bar()

# %%
census_final_data['YouTube channel'].value_counts().plot.bar()

# %%
census_final_data['Snapchat account'].value_counts().plot.bar()

# %%
census_final_data['Screen time opinion - Playing video games'].value_counts().plot.bar()

# %%
census_final_data['Climate change opinion'].value_counts().plot.bar()
